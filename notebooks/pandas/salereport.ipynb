# %%
import pandas as pd
df = pd.read_csv('SalesJan2009.csv')
df
# Out:
#     Transaction_date   Product Price Payment_Type               Name  \
# 0        1/2/09 6:17  Product1  1200   Mastercard           carolina
# 1        1/2/09 4:53  Product1  1200         Visa             Betina
# 2       1/2/09 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3       1/3/09 14:44  Product1  1200         Visa              Gouya
# 4       1/4/09 12:56  Product2  3600         Visa            Gerd W
# 5       1/4/09 13:19  Product1  1200         Visa           LAURENCE
# 6       1/4/09 20:11  Product1  1200   Mastercard              Fleur
# 7       1/2/09 20:09  Product1  1200   Mastercard               adam
# 8       1/4/09 13:17  Product1  1200   Mastercard    Renee Elisabeth
# 9       1/4/09 14:11  Product1  1200         Visa              Aidan
# 10       1/5/09 2:42  Product1  1200       Diners              Stacy
# 11       1/5/09 5:39  Product1  1200         Amex              Heidi
# 12       1/2/09 9:16  Product1  1200   Mastercard              Sean
# ...

# %%
df.groupby('Name').mean()


#df[df['Name']=='carolina']
# Out:
#                       Latitude   Longitude
# Name
# A                    27.770560  -82.679440
# AMY                  30.157780  -95.489170
# Aaron                51.433333   -1.000000
# Abdul-L              40.714170  -74.006390
# Abikay               33.809585 -101.156250
# Adam                 47.250000    6.033333
# Aidan                48.883333    2.150000
# Aideen and Jonathan  46.900000   19.783333
# Ailsa                40.686670  -73.373890
# Alan                 53.450833   -6.154444
# Alessandra           49.250000 -123.133333
# Alex                 33.517220  -82.075830
# Alexandria           40.340830  -76.411670
# Alexia               53.303056   -6.183056
# Alexis               45.190277  -39.479723
# Alfredo A            36.175000 -115.136390
# Alice                54.833333   11.150000
# Alicia               40.800000  -96.666670
# Alicja               47.757500 -122.242780
# Aline                38.545000 -121.739440
# Alison               44.158750  -98.577915
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=998, step=1)

# %%
df.zip.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b094ab85e646> in <module>
# ----> 1 df.zip.unique()
#
# C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'zip'

# %%
df.zip.min()
# Out:
# 95603
