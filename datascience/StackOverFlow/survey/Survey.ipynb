# %%
import pandas as pd
df = pd.read_csv('survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
#df[df['LanguageWorkedWith']=='C++'][['Respondent', 'Country', 'CompTotal', 'CompFreq', 'LanguageWorkedWith']]
#df[df['LanguageWorkedWith'].str.find('C++') != -1]['LanguageWorkedWith']
#df[df['LanguageWorkedWith'].str.contains('C++', regex=False) == True]['LanguageWorkedWith'].str.split(';')
#len(df['LanguageWorkedWith'].str.split(';')[i])
#langs = df[df['LanguageWorkedWith'].str.find('NA') == -1.0]['LanguageWorkedWith'].str.split(';')
#print(len(langs))
#lengths = [i for i in langs]
#print(len(lengths))
import time
start_time = time.time()
languageset = {l for language in df['LanguageWorkedWith'].dropna().str.split(';') for l in language}
print(time.time() - start_time)
print(languageset)
print(len(languageset))
# Out:
# 0.127000093460083
# {'Swift', 'Ruby', 'C++', 'PHP', 'Dart', 'Java', 'Kotlin', 'Go', 'Rust', 'C', 'VBA', 'R', 'HTML/CSS', 'Objective-C', 'C#', 'Clojure', 'Assembly', 'JavaScript', 'Scala', 'Other(s):', 'WebAssembly', 'F#', 'Elixir', 'SQL', 'Erlang', 'Bash/Shell/PowerShell', 'Python', 'TypeScript'}
# 28
