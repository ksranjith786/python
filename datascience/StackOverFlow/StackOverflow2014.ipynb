# %%
#import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv('C:\\Users\\rk185212\\Google Drive\\Learning\\Git\\python\\survey\\stackoverflow\\2014 Stack Overflow Survey Responses\\2014 Stack Overflow Survey Responses.csv'
                         , header=[0,1]
                        )

#print(df.columns)
#print(df.iloc[:, 0:2])
rows_count = df.values
#plt.plot()
#print(rows_count)

# %%
df
# Out:
#      What Country do you live in?     Unnamed: 1_level_0  \
#                          Response Other (please specify)
# 0                           India                    NaN
# 1                        Thailand                    NaN
# 2                            Iran                    NaN
# 3                         Ukraine                    NaN
# 4                           India                    NaN
# 5                         Denmark                    NaN
# 6                           India                    NaN
# 7                           India                    NaN
# 8                  United Kingdom                    NaN
# 9                     New Zealand                    NaN
# 10                         Israel                    NaN
# 11                   Saudi Arabia                    NaN
# 12                 Czech Republic                    NaN
# 13                          India                    NaN
# ...
