# %%
import pandas as pd
df = pd.read_csv('http://bit.ly/uforeports')
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
df.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
df['Shape Reported'].unique()
# Out:
# array(['TRIANGLE', 'OTHER', 'OVAL', 'DISK', 'LIGHT', 'CIRCLE', 'CIGAR',
#        'CYLINDER', 'FIREBALL', 'SPHERE', nan, 'RECTANGLE', 'FORMATION',
#        'FLASH', 'CHEVRON', 'EGG', 'CONE', 'DIAMOND', 'VARIOUS',
#        'TEARDROP', 'CROSS', 'DELTA', 'ROUND', 'DOME', 'PYRAMID',
#        'CRESCENT', 'FLARE', 'HEXAGON'], dtype=object)

# %%
df['Shape Reported'].mode()
# Out:
# 0    LIGHT
# dtype: object

# %%
df.isnull()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 0      False             True           False  False  False
# 1      False             True           False  False  False
# 2      False             True           False  False  False
# 3      False             True           False  False  False
# 4      False             True           False  False  False
# 5      False             True           False  False  False
# 6      False             True           False  False  False
# 7      False             True           False  False  False
# 8      False             True           False  False  False
# 9      False             True           False  False  False
# 10     False             True           False  False  False
# 11     False             True           False  False  False
# 12     False            False           False  False  False
# 13     False             True           False  False  False
# 14     False             True           False  False  False
# ...

# %%
df.notnull()
# Out:
#         City  Colors Reported  Shape Reported  State  Time
# 0       True            False            True   True  True
# 1       True            False            True   True  True
# 2       True            False            True   True  True
# 3       True            False            True   True  True
# 4       True            False            True   True  True
# 5       True            False            True   True  True
# 6       True            False            True   True  True
# 7       True            False            True   True  True
# 8       True            False            True   True  True
# 9       True            False            True   True  True
# 10      True            False            True   True  True
# 11      True            False            True   True  True
# 12      True             True            True   True  True
# 13      True            False            True   True  True
# 14      True            False            True   True  True
# ...

# %%
df.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
df.isnull().count()
# Out:
# City               18241
# Colors Reported    18241
# Shape Reported     18241
# State              18241
# Time               18241
# dtype: int64

# %%
df['City'].unique().size
# Out:
# 6477

# %%
df[df['City'].isnull()]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
df.shape
# Out:
# (18241, 5)

# %%
df.dropna().shape
# Out:
# (2486, 5)

# %%
# Drop rows from data frame if any of the column in a row has NaN
df.dropna(how='any').shape
# Out:
# (2486, 5)

# %%
# Drop rows from data frame if all of the columns in a row has NaN
df.dropna(how='all').shape
# Out:
# (18241, 5)

# %%
# Drop rows from data frame if any of the given subset columns in a row has NaN
df.dropna(subset=['City', 'Shape Reported'], how='any').shape
# Out:
# (15576, 5)

# %%
# Drop rows from data frame if all the given subset columns in a row has NaN
df.dropna(subset=['City', 'Shape Reported'], how='all').shape
# Out:
# (18237, 5)

# %%
df['City'].value_counts()
# Out:
# Seattle                 187
# New York City           161
# Phoenix                 137
# Houston                 108
# Las Vegas               105
# Portland                102
# San Diego               101
# Los Angeles              98
# Chicago                  73
# Austin                   62
# Miami                    60
# Tucson                   58
# Columbus                 55
# Albuquerque              54
# Tacoma                   52
# Dallas                   52
# St. Louis                51
# San Francisco            51
# Spokane                  49
# Salem                    48
# Jacksonville             48
# Auburn                   48
# Sacramento               46
# Salt Lake City           46
# Gilbert                  45
# Denver                   44
# Colorado Springs         44
# Springfield              43
# San Antonio              43
# San Jose                 42
#                        ...
# Spranger                  1
# Rancho                    1
# ...

# %%
df['City'].value_counts(dropna=False)
# Out:
# Seattle                 187
# New York City           161
# Phoenix                 137
# Houston                 108
# Las Vegas               105
# Portland                102
# San Diego               101
# Los Angeles              98
# Chicago                  73
# Austin                   62
# Miami                    60
# Tucson                   58
# Columbus                 55
# Albuquerque              54
# Dallas                   52
# Tacoma                   52
# San Francisco            51
# St. Louis                51
# Spokane                  49
# Jacksonville             48
# Salem                    48
# Auburn                   48
# Salt Lake City           46
# Sacramento               46
# Gilbert                  45
# Colorado Springs         44
# Denver                   44
# Springfield              43
# San Antonio              43
# Reno                     42
#                        ...
# Spranger                  1
# Rancho                    1
# ...

# %%
df['City'].size
# Out:
# 18241

# %%
df[df['City'].isnull()].size
# Out:
# 125
